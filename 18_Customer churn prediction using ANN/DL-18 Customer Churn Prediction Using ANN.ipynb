# %% [markdown]
# # Customer churn prediction using ANN | Deep Learning Tutorial 18 (Tensorflow2.0, Keras & Python)
#
# In this video we will build a customer churn prediction model using **artificial neural network or ANN.** Customer churn measures how and why are customers leaving the business. We will use telecom customer churn dataset from __kaggle__ (link below) and build a deep learning model for churn prediction. We will also understand **precision, recalll and accuracy** of this model by using **confusion matrix and classification report.**
#
# Code: https://github.com/codebasics/deep-learning-keras-tf-tutorial/blob/master/11_chrun_prediction/churn.ipynb <br>
# Credit: https://www.youtube.com/watch?v=MSBY28IJ47U&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=18 <br>
# Kaggle: https://www.kaggle.com/blastchar/telco-customer-churn
# #### Owner: Codebasics

# %% [markdown]
# # 1 Data Preprocessing

# %% [markdown]
# ## 1.1 Import the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## 1.2 Load the dataset
# ### Ways to import CSV files in Google Colab
# link: https://www.geeksforgeeks.org/ways-to-import-csv-files-in-google-colab/

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('Customer-Churn.csv')
# Out:
#      <input type="file" id="files-e5482219-e660-4326-a260-dd46eaec37ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5482219-e660-4326-a260-dd46eaec37ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Customer-Churn.csv to Customer-Churn (4).csv

# %% [markdown]
# ### Data exploration

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 4074  0946-CLJTI    Male              1  ...          98.70       5812.6    Yes
# 1777  2155-AMQRX  Female              0  ...          54.90      1505.15     No
# 327   5804-LEPIM  Female              1  ...          70.35       139.05    Yes
# 5410  4049-ZPALD  Female              0  ...          99.00       6375.8     No
# 1983  7336-RLLRH    Male              0  ...          80.85      2204.35     No
#
# [5 rows x 21 columns]

# %%
df.shape # rows=7043 * columns=21
# Out:
# (7043, 21)

# %% [markdown]
# We have here, total 20 independent variables and 1 dependent variable

# %%
df.dtypes # TotalCharges & Churn, are object, so we need to convert them into values
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values # it is string and we need numeric values, so lets convert this into numeric values.
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric(df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-06ba430a4ba5> in <module>()
# ----> 1 pd.to_numeric(df.TotalCharges)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     182         try:
#     183             values, _ = lib.maybe_convert_numeric(
# --> 184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#     186         except (ValueError, TypeError):
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %% [markdown]
# As, some values, seems like not numbers but blank string. Let's find out such rows

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull().sum()
# Out:
# 11

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 488   4472-LVYGI  Female              0  ...          52.55                  No
# 753   3115-CZMZD    Male              0  ...          20.25                  No
# 936   5709-LVOEQ  Female              0  ...          80.85                  No
# 1082  4367-NUYAO    Male              0  ...          25.75                  No
# 1340  1371-DWPAZ  Female              0  ...          56.05                  No
# 3331  7644-OMVMY    Male              0  ...          19.85                  No
# 3826  3213-VVOLG    Male              0  ...          25.35                  No
# 4380  2520-SGTTA  Female              0  ...          20.00                  No
# 5218  2923-ARZLG    Male              0  ...          19.70                  No
# 6670  4075-WKNIU  Female              0  ...          73.35                  No
# 6754  2775-SEFEE    Male              0  ...          61.90                  No
#
# ...

# %%
df.drop('customerID',axis='columns',inplace=True)
df.sample(5)
# Out:
#       gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 2080    Male              1     Yes  ...          84.10       5981.65    No
# 6134    Male              1      No  ...          44.70         276.5    No
# 355   Female              0      No  ...          80.25           846   Yes
# 1117    Male              0      No  ...          89.45       4577.75    No
# 1176  Female              0      No  ...         109.90        669.45   Yes
#
# [5 rows x 20 columns]

# %%
df.shape # rows=7043 * columns=20, since we dropped 'customerID'
# Out:
# (7043, 20)

# %% [markdown]
# Let's locate the first row where 'TotalCharges' is null

# %%
df.iloc[488].TotalCharges
# Out:
# ' '

# %% [markdown]
# Let's check total dataset, which is without 'TotalCharges' as null

# %%
df[df.TotalCharges != ' '].shape # rows=7032 * columns=20
# Out:
# (7032, 20)

# %% [markdown]
# Let's remove all the 'TotalCharges' as null from the dataset and create new one

# %%
df1 = df[df.TotalCharges!=' ']
df.shape # same matrix array as above
# Out:
# (7043, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# Now, let's convert this into numeric values.

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges) # values required
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df1.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, ...,  346.45,  306.6 , 6844.5 ])

# %% [markdown]
# Let's check the customer, who are not leaving

# %%
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 0     Female              0     Yes  ...          29.85         29.85    No
# 1       Male              0      No  ...          56.95       1889.50    No
# 3       Male              0      No  ...          42.30       1840.75    No
# 6       Male              0      No  ...          89.10       1949.40    No
# 7     Female              0      No  ...          29.75        301.90    No
# ...      ...            ...     ...  ...            ...           ...   ...
# 7037  Female              0      No  ...          21.15       1419.40    No
# 7038    Male              0     Yes  ...          84.80       1990.50    No
# 7039  Female              0     Yes  ...         103.20       7362.90    No
# 7040  Female              0     Yes  ...          29.60        346.45    No
# 7042    Male              0      No  ...         105.65       6844.50    No
#
# [5163 rows x 20 columns]

# %% [markdown]
# Let's check the customer, who are leaving

# %%
df1[df1.Churn=='Yes']
# Out:
#       gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 2       Male              0      No  ...          53.85        108.15   Yes
# 4     Female              0      No  ...          70.70        151.65   Yes
# 5     Female              0      No  ...          99.65        820.50   Yes
# 8     Female              0     Yes  ...         104.80       3046.05   Yes
# 13      Male              0      No  ...         103.70       5036.30   Yes
# ...      ...            ...     ...  ...            ...           ...   ...
# 7021    Male              0      No  ...          59.80        727.80   Yes
# 7026  Female              0      No  ...          44.20        403.35   Yes
# 7032    Male              1      No  ...          75.75         75.75   Yes
# 7034  Female              0      No  ...         102.95       6886.25   Yes
# 7041    Male              1     Yes  ...          74.40        306.60   Yes
#
# [1869 rows x 20 columns]

# %% [markdown]
# ## Data Visualization
# Check, the comparision of customer leaving as per tenure and vice-versa

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel('Tenure')
plt.ylabel('No. of Customer')
plt.title('Customer Churn Prediction Visualization')

plt.hist([tenure_churn_yes,tenure_churn_no],rwidth=0.5,color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# Check, the comparision of customer leaving as per monthly charges and vice-versa

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges

plt.xlabel('MonthlyCharges')
plt.ylabel('No. of Customer')
plt.title('Customer Churn Prediction Visualization')

plt.hist([mc_churn_yes,mc_churn_no],rwidth=0.5,color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# Many of the columns are either yes or no or etc. Let's print the unique values of all in object columns to see data values from the dataset

# %%
def print_unique_values(df):
  for col in df:
      print(f'{col}: {df[col].unique}')

# %%
print_unique_values(df1) # this is printing all 20 independent variables
# Out:
# gender: <bound method Series.unique of 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7032, dtype: object>
# SeniorCitizen: <bound method Series.unique of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: SeniorCitizen, Length: 7032, dtype: int64>
# Partner: <bound method Series.unique of 0       Yes
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041    Yes
# 7042     No
# Name: Partner, Length: 7032, dtype: object>
# Dependents: <bound method Series.unique of 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Dependents, Length: 7032, dtype: object>
# ...

# %%
from pandas.core.algorithms import unique
def print_unique_values(df):
  for col in df:
    if (df[col].dtypes == 'object'):
      print(f'{col}: {df[col].unique()}')

# %%
print_unique_values(df1) # this will print all independent variables, whose 'datatype' is 'object'
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# Some of the columns have 'no internet service' or 'no phone service', etc that can be replaced with a simple "No"

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)
print_unique_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %% [markdown]
# Convert all 'Yes' and 'No' as 1 or 0, in the entire dataset

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
for col in df1:
  df1[col].replace({'Yes':1, 'No':0},inplace=True)

df1
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#       gender  SeniorCitizen  Partner  ...  MonthlyCharges  TotalCharges  Churn
# 0     Female              0        1  ...           29.85         29.85      0
# 1       Male              0        0  ...           56.95       1889.50      0
# 2       Male              0        0  ...           53.85        108.15      1
# 3       Male              0        0  ...           42.30       1840.75      0
# 4     Female              0        0  ...           70.70        151.65      1
# ...      ...            ...      ...  ...             ...           ...    ...
# 7038    Male              0        1  ...           84.80       1990.50      0
# ...

# %% [markdown]
# Search for unique values, which are still left in the dataframe

# %%
for col in df1:
  print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 0]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %% [markdown]
# Let's convert gender 'female' as 1 and 'male' as 0

# %%
df1['gender'].replace({'Female':1, 'Male':0},inplace=True)
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#       gender  SeniorCitizen  Partner  ...  MonthlyCharges  TotalCharges  Churn
# 0          1              0        1  ...           29.85         29.85      0
# 1          0              0        0  ...           56.95       1889.50      0
# 2          0              0        0  ...           53.85        108.15      1
# 3          0              0        0  ...           42.30       1840.75      0
# 4          1              0        0  ...           70.70        151.65      1
# ...      ...            ...      ...  ...             ...           ...    ...
# 7038       0              0        1  ...           84.80       1990.50      0
# ...

# %%
df1.gender.unique()
# Out:
# array([1, 0])

# %% [markdown]
# Now, deploy One hot encoding for categorical columns like 'InternetService', 'Contract' and 'PaymentMethod'
#
# First get the dummies for all these entries

# %%
df1.shape
# Out:
# (7032, 20)

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns # let see all the new columns added into the dataframe
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_0', 'InternetService_DSL',
#        'InternetService_Fiber optic', 'Contract_Month-to-month',
#        'Contract_One year', 'Contract_Two year',
#        'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.shape
# Out:
# (7032, 27)

# %% [markdown]
# Now, all the columns and their data has been transferred into numeric values

# %%
df2.sample(5)
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 305        0  ...                           1
# 6837       0  ...                           0
# 6960       1  ...                           0
# 6124       1  ...                           1
# 5103       1  ...                           0
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_0                            uint8
# ...

# %% [markdown]
# Now, we need to scale all the values of columns 'tenure', 'MonthlyCharges' & 'TotalCharges' between zero & one

# %%
col_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[col_to_scale] = scaler.fit_transform(df2[col_to_scale])
df2
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 0          1  ...                           0
# 1          0  ...                           1
# 2          0  ...                           1
# 3          0  ...                           0
# 4          1  ...                           0
# ...      ...  ...                         ...
# 7038       0  ...                           1
# 7039       1  ...                           0
# 7040       1  ...                           0
# 7041       0  ...                           1
# 7042       0  ...                           0
#
# [7032 rows x 27 columns]

# %% [markdown]
# Let's print unique values from each column of the dataset

# %%
for col in df2:
  print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# ...

# %% [markdown]
# ## Split the dataset into train and test set

# %%
X = df2.drop('Churn', axis='columns')
X
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 0          1  ...                           0
# 1          0  ...                           1
# 2          0  ...                           1
# 3          0  ...                           0
# 4          1  ...                           0
# ...      ...  ...                         ...
# 7038       0  ...                           1
# 7039       1  ...                           0
# 7040       1  ...                           0
# 7041       0  ...                           1
# 7042       0  ...                           0
#
# [7032 rows x 26 columns]

# %%
y = df2['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7032, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 5664       1  ...                           0
# 101        1  ...                           0
# 2621       0  ...                           0
# 392        1  ...                           0
# 1327       0  ...                           0
# 3607       1  ...                           1
# 2773       0  ...                           0
# 1936       1  ...                           0
# 5387       0  ...                           0
# 4331       0  ...                           0
#
# [10 rows x 26 columns]

# %% [markdown]
# ## Perform feature scaling

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.fit_transform(X_test)
X_train
# Out:
# array([[ 0.99698233,  2.31119036, -0.97039363, ...,  1.92743461,
#         -0.70795548, -0.5471529 ],
#        [ 0.99698233, -0.43267747,  1.03050965, ..., -0.51882434,
#          1.4125182 , -0.5471529 ],
#        [-1.0030268 , -0.43267747,  1.03050965, ...,  1.92743461,
#         -0.70795548, -0.5471529 ],
#        ...,
#        [ 0.99698233, -0.43267747,  1.03050965, ...,  1.92743461,
#         -0.70795548, -0.5471529 ],
#        [ 0.99698233, -0.43267747, -0.97039363, ..., -0.51882434,
#         -0.70795548,  1.82764268],
#        [ 0.99698233, -0.43267747,  1.03050965, ..., -0.51882434,
#         -0.70795548,  1.82764268]])

# %%
X_test
# Out:
# array([[-0.94265084, -0.47048291, -0.94669236, ...,  1.81373486,
#         -0.72756294, -0.52939095],
#        [ 1.06083818, -0.47048291, -0.94669236, ...,  1.81373486,
#         -0.72756294, -0.52939095],
#        [ 1.06083818, -0.47048291,  1.05630936, ..., -0.5513485 ,
#         -0.72756294, -0.52939095],
#        ...,
#        [ 1.06083818, -0.47048291, -0.94669236, ..., -0.5513485 ,
#          1.37445154, -0.52939095],
#        [ 1.06083818, -0.47048291, -0.94669236, ..., -0.5513485 ,
#          1.37445154, -0.52939095],
#        [ 1.06083818, -0.47048291, -0.94669236, ..., -0.5513485 ,
#         -0.72756294, -0.52939095]])

# %%
X_train.shape
# Out:
# (5625, 26)

# %% [markdown]
# ## Build a model ANN in tensorflow

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([keras.layers.Dense(26, input_shape=(26,), activation='relu'),
                          keras.layers.Dense(15, activation='relu'),
                          keras.layers.Dense(1, activation='sigmoid')])

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 176/176 [==============================] - 2s 3ms/step - loss: 0.4713 - accuracy: 0.7700
# Epoch 2/5
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4224 - accuracy: 0.7996
# Epoch 3/5
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4141 - accuracy: 0.8073
# Epoch 4/5
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4092 - accuracy: 0.8071
# Epoch 5/5
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4057 - accuracy: 0.8092

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4493 - accuracy: 0.7797
# [0.44928520917892456, 0.7796730399131775]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# array([[0.34502614],
#        [0.3563137 ],
#        [0.00370216],
#        [0.70226717],
#        [0.43215334]], dtype=float32)

# %%
y_pred = []
for element in yp:
  if element > 0.5:
    y_pred.append(1)
  else:
    y_pred.append(0)

# %%
y_pred[:5]
# Out:
# [0, 0, 0, 1, 0]

# %%
y_test[:5]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       999
#            1       0.64      0.54      0.59       408
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.71      0.72      1407
# weighted avg       0.77      0.78      0.77      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
y_test.shape
# Out:
# (1407,)
